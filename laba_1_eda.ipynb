# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fraud_df = pd.read_csv('/content/drive/MyDrive/ИАТУ/Colab Notebooks Local/creditcard_2023.csv')
fraud_df
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %%
fraud_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
fraud_df.Class.value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
fraud_df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
fraud_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Датасет не содержит дупликатов

# %%
fraud_df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Датасет не содержит пропусков

# %%
cols = ['V1','V2','Amount','Class']

# %%
from mlxtend.plotting import scatterplotmatrix
from matplotlib import pyplot as plt
scatterplotmatrix(fraud_df[cols].values, figsize=(10,8), names=cols, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
import seaborn as sns
sns.histplot(fraud_df['V1'], bins=50, kde=True)
plt.xlabel('V1')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_matrix = fraud_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Значения V4,V10,V11,V12,V14 наиболее коррелируют с целевой переменной Class

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

X = fraud_df.values
X
# Out:
# array([[ 0.00000000e+00, -2.60647805e-01, -4.69648450e-01, ...,
#         -1.51045486e-01,  1.79821000e+04,  0.00000000e+00],
#        [ 1.00000000e+00,  9.85099734e-01, -3.56045093e-01, ...,
#         -6.45119230e-02,  6.53137000e+03,  0.00000000e+00],
#        [ 2.00000000e+00, -2.60271613e-01, -9.49384607e-01, ...,
#         -2.44718229e-01,  2.51354000e+03,  0.00000000e+00],
#        ...,
#        [ 5.68627000e+05, -3.11997393e-01, -4.09479480e-03, ...,
#         -2.68741268e-01,  2.35728500e+04,  1.00000000e+00],
#        [ 5.68628000e+05,  6.36870539e-01, -5.16969517e-01, ...,
#         -7.62505739e-02,  1.01608300e+04,  1.00000000e+00],
#        [ 5.68629000e+05, -7.95144165e-01,  4.33236084e-01, ...,
#          7.22936496e-01,  2.14939200e+04,  1.00000000e+00]])

# %%
mms = MinMaxScaler()
X_train_norm = mms.fit_transform(X)
X_train_norm
# Out:
# array([[0.00000000e+00, 5.65090829e-01, 9.11068421e-01, ...,
#         3.34369277e-01, 7.47484360e-01, 0.00000000e+00],
#        [1.75861590e-06, 7.82702730e-01, 9.13159469e-01, ...,
#         3.35113388e-01, 2.70170138e-01, 0.00000000e+00],
#        [3.51723180e-06, 5.65156543e-01, 9.02238126e-01, ...,
#         3.33563775e-01, 1.02690213e-01, 0.00000000e+00],
#        ...,
#        [9.99996483e-01, 5.56120888e-01, 9.19637666e-01, ...,
#         3.33357198e-01, 9.80530156e-01, 1.00000000e+00],
#        [9.99998241e-01, 7.21872734e-01, 9.10197403e-01, ...,
#         3.35012446e-01, 4.21461180e-01, 1.00000000e+00],
#        [1.00000000e+00, 4.71722979e-01, 9.27687426e-01, ...,
#         3.41884739e-01, 8.93871676e-01, 1.00000000e+00]])

# %%
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[-1.73204776, -0.2606478 , -0.46964845, ..., -0.15104549,
#          0.85844694, -1.        ],
#        [-1.73204167,  0.98509973, -0.35604509, ..., -0.06451192,
#         -0.79636931, -1.        ],
#        [-1.73203558, -0.26027161, -0.94938461, ..., -0.24471823,
#         -1.37701093, -1.        ],
#        ...,
#        [ 1.73203558, -0.31199739, -0.00409479, ..., -0.26874127,
#          1.66640101,  1.        ],
#        [ 1.73204167,  0.63687054, -0.51696952, ..., -0.07625057,
#         -0.27185346,  1.        ],
#        [ 1.73204776, -0.79514417,  0.43323608, ...,  0.7229365 ,
#          1.3659619 ,  1.        ]])

# %% [markdown]
# Вывод:
# В ходе лабораторной работы мы осуществили импорт датасета с использованием библиотеки pandas. Проанализировали данные, осматривая их на предмет качества, полноты и структуры. Провели графический анализ данных, используя различные инструменты визуализации. Проанализировали корреляцию между различными признаками в наших данных.
# Стандартизировали данные, приводя их к общему диапазону значений, что упрощает последующий анализ и обработку данных.
